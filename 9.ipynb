# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

model = models.Sequential()

# First layer
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Second layer
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Third layer
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# fourth layer

model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# fifth layer

model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# final
model.add(ks.layers.Flatten())
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  batch_normalization (Batch  (None, 32, 32, 128)       512
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_1 (Bat  (None, 32, 32, 128)       512
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 128)       0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_2 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_4 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 128)         147584
#
#  batch_normalization_6 (Bat  (None, 4, 4, 128)         512
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 128)         147584
#
#  batch_normalization_7 (Bat  (None, 4, 4, 128)         512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 128)         0
#
#  conv2d_8 (Conv2D)           (None, 2, 2, 128)         147584
#
#  batch_normalization_8 (Bat  (None, 2, 2, 128)         512
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 128)         147584
#
#  batch_normalization_9 (Bat  (None, 2, 2, 128)         512
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1371338 (5.23 MB)
# Trainable params: 1368778 (5.22 MB)
# Non-trainable params: 2560 (10.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 5s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.4, 1.4],
    shear_range=0.2,
    channel_shift_range=0.2,
    fill_mode='nearest',
    validation_split=0.2





    )

train_generator = train_datagen.flow(
    x_train_scaled,
    y_train,
    batch_size=30
)

validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val_scaled,
    y_val,
    batch_size=20
)

# %%
import random
sample = random.choice(range(0,1457))

example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=20
    )

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=200,
                    validation_data=(x_val_scaled, y_val), batch_size=512,
                    )
# Out:
# Epoch 1/200
# 79/79 [==============================] - 42s 276ms/step - loss: 2.1349 - accuracy: 0.1832 - val_loss: 2.5012 - val_accuracy: 0.0929
# Epoch 2/200
# 79/79 [==============================] - 18s 233ms/step - loss: 1.7247 - accuracy: 0.3307 - val_loss: 2.5593 - val_accuracy: 0.1251
# Epoch 3/200
# 79/79 [==============================] - 18s 230ms/step - loss: 1.4868 - accuracy: 0.4397 - val_loss: 3.2969 - val_accuracy: 0.1004
# Epoch 4/200
# 79/79 [==============================] - 18s 230ms/step - loss: 1.2868 - accuracy: 0.5391 - val_loss: 3.9346 - val_accuracy: 0.0976
# Epoch 5/200
# 79/79 [==============================] - 18s 229ms/step - loss: 1.1055 - accuracy: 0.6156 - val_loss: 3.9743 - val_accuracy: 0.1110
# Epoch 6/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.9767 - accuracy: 0.6672 - val_loss: 3.2398 - val_accuracy: 0.1946
# Epoch 7/200
# 79/79 [==============================] - 19s 235ms/step - loss: 0.8650 - accuracy: 0.7114 - val_loss: 1.3211 - val_accuracy: 0.5881
# Epoch 8/200
# 79/79 [==============================] - 19s 235ms/step - loss: 0.7861 - accuracy: 0.7416 - val_loss: 0.9827 - val_accuracy: 0.6688
# Epoch 9/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.7279 - accuracy: 0.7624 - val_loss: 0.9423 - val_accuracy: 0.6993
# Epoch 10/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.6629 - accuracy: 0.7853 - val_loss: 0.8510 - val_accuracy: 0.7326
# Epoch 11/200
# 79/79 [==============================] - 19s 235ms/step - loss: 0.6164 - accuracy: 0.8011 - val_loss: 0.9927 - val_accuracy: 0.7156
# Epoch 12/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.5758 - accuracy: 0.8156 - val_loss: 2.2579 - val_accuracy: 0.4232
# Epoch 13/200
# 79/79 [==============================] - 18s 234ms/step - loss: 0.5313 - accuracy: 0.8321 - val_loss: 0.9204 - val_accuracy: 0.7194
# Epoch 14/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.5108 - accuracy: 0.8381 - val_loss: 0.7186 - val_accuracy: 0.7771
# Epoch 15/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.4661 - accuracy: 0.8520 - val_loss: 0.5943 - val_accuracy: 0.8079
# Epoch 16/200
# 79/79 [==============================] - 18s 234ms/step - loss: 0.4338 - accuracy: 0.8630 - val_loss: 0.6631 - val_accuracy: 0.7904
# Epoch 17/200
# 79/79 [==============================] - 18s 234ms/step - loss: 0.4060 - accuracy: 0.8722 - val_loss: 0.6360 - val_accuracy: 0.8109
# Epoch 18/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.3871 - accuracy: 0.8781 - val_loss: 0.7516 - val_accuracy: 0.7692
# Epoch 19/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.3588 - accuracy: 0.8875 - val_loss: 0.7369 - val_accuracy: 0.7876
# Epoch 20/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.3320 - accuracy: 0.8953 - val_loss: 0.5975 - val_accuracy: 0.8226
# Epoch 21/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.3152 - accuracy: 0.9013 - val_loss: 0.6186 - val_accuracy: 0.8207
# Epoch 22/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.3259 - accuracy: 0.8997 - val_loss: 0.6292 - val_accuracy: 0.8256
# Epoch 23/200
# 79/79 [==============================] - 18s 233ms/step - loss: 0.2933 - accuracy: 0.9077 - val_loss: 0.6289 - val_accuracy: 0.8187
# Epoch 24/200
# 79/79 [==============================] - 18s 227ms/step - loss: 0.2672 - accuracy: 0.9162 - val_loss: 0.6025 - val_accuracy: 0.8255
# Epoch 25/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.2593 - accuracy: 0.9188 - val_loss: 0.5998 - val_accuracy: 0.8330
# Epoch 26/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.2543 - accuracy: 0.9201 - val_loss: 0.8814 - val_accuracy: 0.7752
# Epoch 27/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.2346 - accuracy: 0.9251 - val_loss: 0.5627 - val_accuracy: 0.8424
# Epoch 28/200
# 79/79 [==============================] - 18s 233ms/step - loss: 0.2132 - accuracy: 0.9314 - val_loss: 0.6727 - val_accuracy: 0.8319
# Epoch 29/200
# 79/79 [==============================] - 18s 233ms/step - loss: 0.2227 - accuracy: 0.9297 - val_loss: 0.6229 - val_accuracy: 0.8319
# Epoch 30/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.1971 - accuracy: 0.9388 - val_loss: 0.6180 - val_accuracy: 0.8378
# Epoch 31/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.1825 - accuracy: 0.9423 - val_loss: 0.6064 - val_accuracy: 0.8352
# Epoch 32/200
# 79/79 [==============================] - 18s 233ms/step - loss: 0.2078 - accuracy: 0.9373 - val_loss: 0.6342 - val_accuracy: 0.8317
# Epoch 33/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.1815 - accuracy: 0.9439 - val_loss: 0.6297 - val_accuracy: 0.8465
# Epoch 34/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.1724 - accuracy: 0.9467 - val_loss: 0.6781 - val_accuracy: 0.8336
# Epoch 35/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.1647 - accuracy: 0.9489 - val_loss: 0.6450 - val_accuracy: 0.8356
# Epoch 36/200
# 79/79 [==============================] - 18s 227ms/step - loss: 0.1566 - accuracy: 0.9520 - val_loss: 0.6890 - val_accuracy: 0.8306
# Epoch 37/200
# 79/79 [==============================] - 18s 234ms/step - loss: 0.2030 - accuracy: 0.9376 - val_loss: 0.6416 - val_accuracy: 0.8324
# Epoch 38/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.1466 - accuracy: 0.9545 - val_loss: 0.7638 - val_accuracy: 0.8358
# Epoch 39/200
# 79/79 [==============================] - 18s 234ms/step - loss: 0.1674 - accuracy: 0.9489 - val_loss: 0.6819 - val_accuracy: 0.8379
# Epoch 40/200
# 79/79 [==============================] - 18s 234ms/step - loss: 0.1417 - accuracy: 0.9560 - val_loss: 0.6760 - val_accuracy: 0.8327
# Epoch 41/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.1497 - accuracy: 0.9531 - val_loss: 0.6626 - val_accuracy: 0.8470
# Epoch 42/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.1340 - accuracy: 0.9579 - val_loss: 0.6439 - val_accuracy: 0.8516
# Epoch 43/200
# 79/79 [==============================] - 19s 235ms/step - loss: 0.1195 - accuracy: 0.9642 - val_loss: 0.6522 - val_accuracy: 0.8494
# Epoch 44/200
# 79/79 [==============================] - 18s 233ms/step - loss: 0.1079 - accuracy: 0.9662 - val_loss: 0.6818 - val_accuracy: 0.8510
# Epoch 45/200
# 79/79 [==============================] - 18s 234ms/step - loss: 0.1207 - accuracy: 0.9629 - val_loss: 0.7351 - val_accuracy: 0.8294
# Epoch 46/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.1166 - accuracy: 0.9659 - val_loss: 0.6203 - val_accuracy: 0.8558
# Epoch 47/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.1014 - accuracy: 0.9696 - val_loss: 0.6109 - val_accuracy: 0.8496
# Epoch 48/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.1129 - accuracy: 0.9655 - val_loss: 0.6370 - val_accuracy: 0.8562
# Epoch 49/200
# 79/79 [==============================] - 18s 228ms/step - loss: 0.1010 - accuracy: 0.9685 - val_loss: 0.6830 - val_accuracy: 0.8501
# Epoch 50/200
# 79/79 [==============================] - 18s 233ms/step - loss: 0.0986 - accuracy: 0.9704 - val_loss: 0.6899 - val_accuracy: 0.8464
# Epoch 51/200
# 41/79 [==============>...............] - ETA: 8s - loss: 0.1216 - accuracy: 0.9632

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
