# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

model = models.Sequential()

# First layer
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))

# Second layer
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))

# Third layer
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# fourth layer

model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# fifth layer

model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# final
model.add(ks.layers.Flatten())
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 32, 32, 128)       3584
#
#  batch_normalization_10 (Ba  (None, 32, 32, 128)       512
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)       147584
#
#  batch_normalization_11 (Ba  (None, 32, 32, 128)       512
#  tchNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_12 (Ba  (None, 16, 16, 128)       512
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_13 (Ba  (None, 16, 16, 128)       512
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_14 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_15 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 4, 4, 128)         0
#
#  conv2d_16 (Conv2D)          (None, 4, 4, 128)         147584
#
#  batch_normalization_16 (Ba  (None, 4, 4, 128)         512
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 4, 4, 128)         147584
#
#  batch_normalization_17 (Ba  (None, 4, 4, 128)         512
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 2, 2, 128)         0
#
#  conv2d_18 (Conv2D)          (None, 2, 2, 128)         147584
#
#  batch_normalization_18 (Ba  (None, 2, 2, 128)         512
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 2, 2, 128)         147584
#
#  batch_normalization_19 (Ba  (None, 2, 2, 128)         512
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1387786 (5.29 MB)
# Trainable params: 1385226 (5.28 MB)
# Non-trainable params: 2560 (10.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=200,
                 batch_size= 512, validation_data=(x_val_scaled, y_val))
# Out:
# Epoch 1/200
# 79/79 [==============================] - 32s 260ms/step - loss: 2.1656 - accuracy: 0.1909 - val_loss: 2.4826 - val_accuracy: 0.0952
# Epoch 2/200
# 79/79 [==============================] - 18s 231ms/step - loss: 1.7323 - accuracy: 0.3237 - val_loss: 4.1722 - val_accuracy: 0.1014
# Epoch 3/200
# 79/79 [==============================] - 18s 230ms/step - loss: 1.5046 - accuracy: 0.4383 - val_loss: 2.8263 - val_accuracy: 0.0975
# Epoch 4/200
# 79/79 [==============================] - 18s 225ms/step - loss: 1.3074 - accuracy: 0.5337 - val_loss: 5.4406 - val_accuracy: 0.0952
# Epoch 5/200
# 79/79 [==============================] - 18s 226ms/step - loss: 1.1239 - accuracy: 0.6108 - val_loss: 2.7640 - val_accuracy: 0.1709
# Epoch 6/200
# 79/79 [==============================] - 18s 226ms/step - loss: 1.0068 - accuracy: 0.6575 - val_loss: 2.2530 - val_accuracy: 0.2867
# Epoch 7/200
# 79/79 [==============================] - 18s 231ms/step - loss: 0.8825 - accuracy: 0.7025 - val_loss: 1.5171 - val_accuracy: 0.5229
# Epoch 8/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.8126 - accuracy: 0.7290 - val_loss: 1.0094 - val_accuracy: 0.6594
# Epoch 9/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.7355 - accuracy: 0.7595 - val_loss: 0.7718 - val_accuracy: 0.7426
# Epoch 10/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.6671 - accuracy: 0.7825 - val_loss: 0.8974 - val_accuracy: 0.7185
# Epoch 11/200
# 79/79 [==============================] - 18s 231ms/step - loss: 0.6145 - accuracy: 0.8015 - val_loss: 0.9539 - val_accuracy: 0.6996
# Epoch 12/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.5910 - accuracy: 0.8097 - val_loss: 0.7451 - val_accuracy: 0.7600
# Epoch 13/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.5373 - accuracy: 0.8288 - val_loss: 0.6558 - val_accuracy: 0.7907
# Epoch 14/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.4881 - accuracy: 0.8454 - val_loss: 0.7435 - val_accuracy: 0.7683
# Epoch 15/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.4915 - accuracy: 0.8449 - val_loss: 0.6309 - val_accuracy: 0.8087
# Epoch 16/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.4357 - accuracy: 0.8615 - val_loss: 0.6158 - val_accuracy: 0.8091
# Epoch 17/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.4390 - accuracy: 0.8623 - val_loss: 0.6241 - val_accuracy: 0.8069
# Epoch 18/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.3952 - accuracy: 0.8741 - val_loss: 0.6304 - val_accuracy: 0.8109
# Epoch 19/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.3724 - accuracy: 0.8822 - val_loss: 0.5891 - val_accuracy: 0.8254
# Epoch 20/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.3552 - accuracy: 0.8878 - val_loss: 0.6491 - val_accuracy: 0.8106
# Epoch 21/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.3231 - accuracy: 0.9013 - val_loss: 0.5866 - val_accuracy: 0.8315
# Epoch 22/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.3128 - accuracy: 0.9005 - val_loss: 0.6656 - val_accuracy: 0.8134
# Epoch 23/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.2962 - accuracy: 0.9071 - val_loss: 0.5340 - val_accuracy: 0.8438
# Epoch 24/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.2718 - accuracy: 0.9140 - val_loss: 0.6422 - val_accuracy: 0.8259
# Epoch 25/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.2879 - accuracy: 0.9087 - val_loss: 0.6493 - val_accuracy: 0.8158
# Epoch 26/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.2746 - accuracy: 0.9123 - val_loss: 0.6445 - val_accuracy: 0.8218
# Epoch 27/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.2607 - accuracy: 0.9184 - val_loss: 0.6926 - val_accuracy: 0.8078
# Epoch 28/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.2345 - accuracy: 0.9267 - val_loss: 0.6155 - val_accuracy: 0.8322
# Epoch 29/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.2286 - accuracy: 0.9288 - val_loss: 0.6491 - val_accuracy: 0.8295
# Epoch 30/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.2065 - accuracy: 0.9347 - val_loss: 0.5940 - val_accuracy: 0.8416
# Epoch 31/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.1929 - accuracy: 0.9393 - val_loss: 0.6828 - val_accuracy: 0.8255
# Epoch 32/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.1922 - accuracy: 0.9403 - val_loss: 0.6184 - val_accuracy: 0.8378
# Epoch 33/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.1919 - accuracy: 0.9391 - val_loss: 0.6463 - val_accuracy: 0.8361
# Epoch 34/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.1730 - accuracy: 0.9463 - val_loss: 0.6397 - val_accuracy: 0.8333
# Epoch 35/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.1789 - accuracy: 0.9442 - val_loss: 0.6615 - val_accuracy: 0.8327
# Epoch 36/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.1583 - accuracy: 0.9505 - val_loss: 0.6966 - val_accuracy: 0.8325
# Epoch 37/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.1681 - accuracy: 0.9475 - val_loss: 0.6303 - val_accuracy: 0.8387
# Epoch 38/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.1519 - accuracy: 0.9524 - val_loss: 0.6422 - val_accuracy: 0.8460
# Epoch 39/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.1533 - accuracy: 0.9521 - val_loss: 0.5902 - val_accuracy: 0.8533
# Epoch 40/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.1271 - accuracy: 0.9607 - val_loss: 0.7954 - val_accuracy: 0.8291
# Epoch 41/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.1413 - accuracy: 0.9564 - val_loss: 0.6180 - val_accuracy: 0.8498
# Epoch 42/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.1475 - accuracy: 0.9553 - val_loss: 0.6735 - val_accuracy: 0.8342
# Epoch 43/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.1477 - accuracy: 0.9535 - val_loss: 0.7213 - val_accuracy: 0.8321
# Epoch 44/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.1250 - accuracy: 0.9610 - val_loss: 0.6939 - val_accuracy: 0.8383
# Epoch 45/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.1172 - accuracy: 0.9632 - val_loss: 0.6398 - val_accuracy: 0.8516
# Epoch 46/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.1016 - accuracy: 0.9679 - val_loss: 0.6477 - val_accuracy: 0.8505
# Epoch 47/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.1085 - accuracy: 0.9668 - val_loss: 0.6532 - val_accuracy: 0.8544
# Epoch 48/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.1060 - accuracy: 0.9667 - val_loss: 0.7965 - val_accuracy: 0.8289
# Epoch 49/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.1033 - accuracy: 0.9687 - val_loss: 0.6091 - val_accuracy: 0.8636
# Epoch 50/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.1050 - accuracy: 0.9687 - val_loss: 0.7501 - val_accuracy: 0.8303
# Epoch 51/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.0988 - accuracy: 0.9695 - val_loss: 0.6859 - val_accuracy: 0.8482
# Epoch 52/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.1034 - accuracy: 0.9688 - val_loss: 0.7419 - val_accuracy: 0.8463
# Epoch 53/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0902 - accuracy: 0.9721 - val_loss: 0.6224 - val_accuracy: 0.8595
# Epoch 54/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0906 - accuracy: 0.9723 - val_loss: 0.6911 - val_accuracy: 0.8431
# Epoch 55/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0836 - accuracy: 0.9752 - val_loss: 0.7611 - val_accuracy: 0.8415
# Epoch 56/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0847 - accuracy: 0.9745 - val_loss: 0.6738 - val_accuracy: 0.8574
# Epoch 57/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0793 - accuracy: 0.9754 - val_loss: 0.7198 - val_accuracy: 0.8530
# Epoch 58/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0895 - accuracy: 0.9724 - val_loss: 0.7911 - val_accuracy: 0.8392
# Epoch 59/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0978 - accuracy: 0.9704 - val_loss: 0.8626 - val_accuracy: 0.8227
# Epoch 60/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0991 - accuracy: 0.9706 - val_loss: 0.6787 - val_accuracy: 0.8550
# Epoch 61/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0750 - accuracy: 0.9768 - val_loss: 0.6823 - val_accuracy: 0.8552
# Epoch 62/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0808 - accuracy: 0.9755 - val_loss: 0.7112 - val_accuracy: 0.8488
# Epoch 63/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0843 - accuracy: 0.9738 - val_loss: 0.7988 - val_accuracy: 0.8289
# Epoch 64/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.0891 - accuracy: 0.9735 - val_loss: 0.9319 - val_accuracy: 0.8114
# Epoch 65/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0929 - accuracy: 0.9724 - val_loss: 0.6376 - val_accuracy: 0.8602
# Epoch 66/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0801 - accuracy: 0.9766 - val_loss: 0.6425 - val_accuracy: 0.8573
# Epoch 67/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0725 - accuracy: 0.9779 - val_loss: 0.7044 - val_accuracy: 0.8537
# Epoch 68/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0878 - accuracy: 0.9734 - val_loss: 0.7228 - val_accuracy: 0.8487
# Epoch 69/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0726 - accuracy: 0.9775 - val_loss: 0.7214 - val_accuracy: 0.8510
# Epoch 70/200
# 79/79 [==============================] - 18s 229ms/step - loss: 0.0689 - accuracy: 0.9789 - val_loss: 0.6527 - val_accuracy: 0.8611
# Epoch 71/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0676 - accuracy: 0.9791 - val_loss: 0.7014 - val_accuracy: 0.8534
# Epoch 72/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0686 - accuracy: 0.9791 - val_loss: 0.7086 - val_accuracy: 0.8526
# Epoch 73/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0717 - accuracy: 0.9777 - val_loss: 0.6824 - val_accuracy: 0.8630
# Epoch 74/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0659 - accuracy: 0.9803 - val_loss: 0.7756 - val_accuracy: 0.8513
# Epoch 75/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0628 - accuracy: 0.9821 - val_loss: 0.7404 - val_accuracy: 0.8560
# Epoch 76/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0900 - accuracy: 0.9730 - val_loss: 0.8614 - val_accuracy: 0.8287
# Epoch 77/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0693 - accuracy: 0.9782 - val_loss: 0.6956 - val_accuracy: 0.8599
# Epoch 78/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0623 - accuracy: 0.9805 - val_loss: 0.6586 - val_accuracy: 0.8624
# Epoch 79/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0548 - accuracy: 0.9835 - val_loss: 0.7431 - val_accuracy: 0.8489
# Epoch 80/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0661 - accuracy: 0.9798 - val_loss: 0.7487 - val_accuracy: 0.8511
# Epoch 81/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0623 - accuracy: 0.9815 - val_loss: 0.6790 - val_accuracy: 0.8678
# Epoch 82/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0552 - accuracy: 0.9819 - val_loss: 0.8371 - val_accuracy: 0.8437
# Epoch 83/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0608 - accuracy: 0.9819 - val_loss: 0.6975 - val_accuracy: 0.8616
# Epoch 84/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0518 - accuracy: 0.9842 - val_loss: 0.6943 - val_accuracy: 0.8659
# Epoch 85/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0712 - accuracy: 0.9783 - val_loss: 0.7888 - val_accuracy: 0.8488
# Epoch 86/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0603 - accuracy: 0.9822 - val_loss: 0.7465 - val_accuracy: 0.8586
# Epoch 87/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0752 - accuracy: 0.9780 - val_loss: 0.6668 - val_accuracy: 0.8594
# Epoch 88/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0600 - accuracy: 0.9822 - val_loss: 0.8169 - val_accuracy: 0.8398
# Epoch 89/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0531 - accuracy: 0.9836 - val_loss: 0.7246 - val_accuracy: 0.8631
# Epoch 90/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0539 - accuracy: 0.9841 - val_loss: 0.7495 - val_accuracy: 0.8546
# Epoch 91/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0543 - accuracy: 0.9836 - val_loss: 0.7310 - val_accuracy: 0.8594
# Epoch 92/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0523 - accuracy: 0.9841 - val_loss: 0.8359 - val_accuracy: 0.8390
# Epoch 93/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0576 - accuracy: 0.9825 - val_loss: 0.7281 - val_accuracy: 0.8588
# Epoch 94/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0536 - accuracy: 0.9841 - val_loss: 0.7295 - val_accuracy: 0.8564
# Epoch 95/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0544 - accuracy: 0.9834 - val_loss: 0.6938 - val_accuracy: 0.8613
# Epoch 96/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0629 - accuracy: 0.9808 - val_loss: 0.7205 - val_accuracy: 0.8635
# Epoch 97/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0514 - accuracy: 0.9841 - val_loss: 0.7783 - val_accuracy: 0.8522
# Epoch 98/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0533 - accuracy: 0.9840 - val_loss: 0.7232 - val_accuracy: 0.8590
# Epoch 99/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0783 - accuracy: 0.9772 - val_loss: 0.8363 - val_accuracy: 0.8404
# Epoch 100/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0622 - accuracy: 0.9819 - val_loss: 0.7860 - val_accuracy: 0.8445
# Epoch 101/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0540 - accuracy: 0.9842 - val_loss: 0.6669 - val_accuracy: 0.8657
# Epoch 102/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0589 - accuracy: 0.9820 - val_loss: 0.7447 - val_accuracy: 0.8615
# Epoch 103/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0524 - accuracy: 0.9844 - val_loss: 0.7165 - val_accuracy: 0.8623
# Epoch 104/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0544 - accuracy: 0.9832 - val_loss: 0.7298 - val_accuracy: 0.8576
# Epoch 105/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0458 - accuracy: 0.9865 - val_loss: 0.7394 - val_accuracy: 0.8645
# Epoch 106/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0525 - accuracy: 0.9848 - val_loss: 0.6624 - val_accuracy: 0.8687
# Epoch 107/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0470 - accuracy: 0.9857 - val_loss: 0.7852 - val_accuracy: 0.8538
# Epoch 108/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0673 - accuracy: 0.9792 - val_loss: 0.6944 - val_accuracy: 0.8647
# Epoch 109/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0508 - accuracy: 0.9850 - val_loss: 0.7410 - val_accuracy: 0.8636
# Epoch 110/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0442 - accuracy: 0.9866 - val_loss: 0.7937 - val_accuracy: 0.8548
# Epoch 111/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0447 - accuracy: 0.9869 - val_loss: 0.7332 - val_accuracy: 0.8634
# Epoch 112/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0404 - accuracy: 0.9877 - val_loss: 0.7493 - val_accuracy: 0.8623
# Epoch 113/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0463 - accuracy: 0.9861 - val_loss: 0.7385 - val_accuracy: 0.8674
# Epoch 114/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0421 - accuracy: 0.9870 - val_loss: 0.7043 - val_accuracy: 0.8667
# Epoch 115/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0400 - accuracy: 0.9886 - val_loss: 0.7348 - val_accuracy: 0.8685
# Epoch 116/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0597 - accuracy: 0.9829 - val_loss: 0.7909 - val_accuracy: 0.8602
# Epoch 117/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0530 - accuracy: 0.9846 - val_loss: 1.1274 - val_accuracy: 0.8224
# Epoch 118/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0544 - accuracy: 0.9836 - val_loss: 1.0059 - val_accuracy: 0.8308
# Epoch 119/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0518 - accuracy: 0.9847 - val_loss: 0.7209 - val_accuracy: 0.8655
# Epoch 120/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0395 - accuracy: 0.9882 - val_loss: 0.7257 - val_accuracy: 0.8636
# Epoch 121/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0379 - accuracy: 0.9884 - val_loss: 0.7760 - val_accuracy: 0.8617
# Epoch 122/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0469 - accuracy: 0.9862 - val_loss: 0.7346 - val_accuracy: 0.8632
# Epoch 123/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0398 - accuracy: 0.9882 - val_loss: 0.7941 - val_accuracy: 0.8625
# Epoch 124/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0376 - accuracy: 0.9890 - val_loss: 0.7898 - val_accuracy: 0.8600
# Epoch 125/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0391 - accuracy: 0.9888 - val_loss: 0.7620 - val_accuracy: 0.8630
# Epoch 126/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0324 - accuracy: 0.9896 - val_loss: 0.8105 - val_accuracy: 0.8603
# Epoch 127/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0367 - accuracy: 0.9893 - val_loss: 0.8004 - val_accuracy: 0.8618
# Epoch 128/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0531 - accuracy: 0.9845 - val_loss: 0.7102 - val_accuracy: 0.8654
# Epoch 129/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0370 - accuracy: 0.9885 - val_loss: 0.7428 - val_accuracy: 0.8663
# Epoch 130/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0539 - accuracy: 0.9841 - val_loss: 0.8405 - val_accuracy: 0.8543
# Epoch 131/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0399 - accuracy: 0.9886 - val_loss: 0.7516 - val_accuracy: 0.8693
# Epoch 132/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0302 - accuracy: 0.9905 - val_loss: 0.7944 - val_accuracy: 0.8621
# Epoch 133/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0381 - accuracy: 0.9881 - val_loss: 0.7463 - val_accuracy: 0.8692
# Epoch 134/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0361 - accuracy: 0.9896 - val_loss: 0.8684 - val_accuracy: 0.8508
# Epoch 135/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0831 - accuracy: 0.9764 - val_loss: 0.7594 - val_accuracy: 0.8562
# Epoch 136/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0459 - accuracy: 0.9858 - val_loss: 0.7809 - val_accuracy: 0.8630
# Epoch 137/200
# 79/79 [==============================] - 18s 231ms/step - loss: 0.0431 - accuracy: 0.9880 - val_loss: 0.7508 - val_accuracy: 0.8655
# Epoch 138/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0384 - accuracy: 0.9879 - val_loss: 0.8604 - val_accuracy: 0.8544
# Epoch 139/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0344 - accuracy: 0.9898 - val_loss: 0.8034 - val_accuracy: 0.8628
# Epoch 140/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0339 - accuracy: 0.9901 - val_loss: 0.7713 - val_accuracy: 0.8614
# Epoch 141/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0424 - accuracy: 0.9870 - val_loss: 0.7583 - val_accuracy: 0.8660
# Epoch 142/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0362 - accuracy: 0.9894 - val_loss: 0.8326 - val_accuracy: 0.8549
# Epoch 143/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0639 - accuracy: 0.9816 - val_loss: 0.8129 - val_accuracy: 0.8566
# Epoch 144/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0459 - accuracy: 0.9869 - val_loss: 0.6990 - val_accuracy: 0.8708
# Epoch 145/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0312 - accuracy: 0.9904 - val_loss: 0.7488 - val_accuracy: 0.8723
# Epoch 146/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0434 - accuracy: 0.9876 - val_loss: 0.6699 - val_accuracy: 0.8678
# Epoch 147/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0482 - accuracy: 0.9857 - val_loss: 0.9288 - val_accuracy: 0.8369
# Epoch 148/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0344 - accuracy: 0.9887 - val_loss: 0.7484 - val_accuracy: 0.8691
# Epoch 149/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0312 - accuracy: 0.9906 - val_loss: 0.8031 - val_accuracy: 0.8646
# Epoch 150/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0332 - accuracy: 0.9902 - val_loss: 0.7424 - val_accuracy: 0.8691
# Epoch 151/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0325 - accuracy: 0.9899 - val_loss: 0.7744 - val_accuracy: 0.8680
# Epoch 152/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0273 - accuracy: 0.9918 - val_loss: 0.7616 - val_accuracy: 0.8661
# Epoch 153/200
# 79/79 [==============================] - 18s 231ms/step - loss: 0.0317 - accuracy: 0.9908 - val_loss: 0.7395 - val_accuracy: 0.8696
# Epoch 154/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0322 - accuracy: 0.9899 - val_loss: 0.7303 - val_accuracy: 0.8694
# Epoch 155/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0318 - accuracy: 0.9906 - val_loss: 0.7987 - val_accuracy: 0.8639
# Epoch 156/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0499 - accuracy: 0.9851 - val_loss: 0.7298 - val_accuracy: 0.8688
# Epoch 157/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0429 - accuracy: 0.9858 - val_loss: 0.8227 - val_accuracy: 0.8627
# Epoch 158/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0374 - accuracy: 0.9884 - val_loss: 0.8013 - val_accuracy: 0.8664
# Epoch 159/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0430 - accuracy: 0.9876 - val_loss: 0.7462 - val_accuracy: 0.8725
# Epoch 160/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0480 - accuracy: 0.9859 - val_loss: 0.6913 - val_accuracy: 0.8737
# Epoch 161/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0310 - accuracy: 0.9909 - val_loss: 0.9041 - val_accuracy: 0.8546
# Epoch 162/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0319 - accuracy: 0.9901 - val_loss: 0.7346 - val_accuracy: 0.8707
# Epoch 163/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0401 - accuracy: 0.9885 - val_loss: 0.7873 - val_accuracy: 0.8620
# Epoch 164/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0348 - accuracy: 0.9898 - val_loss: 0.8393 - val_accuracy: 0.8563
# Epoch 165/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0282 - accuracy: 0.9913 - val_loss: 0.7640 - val_accuracy: 0.8738
# Epoch 166/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0279 - accuracy: 0.9912 - val_loss: 0.8239 - val_accuracy: 0.8610
# Epoch 167/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0284 - accuracy: 0.9918 - val_loss: 0.9204 - val_accuracy: 0.8554
# Epoch 168/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0428 - accuracy: 0.9866 - val_loss: 0.7960 - val_accuracy: 0.8619
# Epoch 169/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0346 - accuracy: 0.9897 - val_loss: 0.7152 - val_accuracy: 0.8712
# Epoch 170/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0271 - accuracy: 0.9913 - val_loss: 0.9974 - val_accuracy: 0.8409
# Epoch 171/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0285 - accuracy: 0.9909 - val_loss: 0.7927 - val_accuracy: 0.8666
# Epoch 172/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0299 - accuracy: 0.9907 - val_loss: 0.7259 - val_accuracy: 0.8732
# Epoch 173/200
# 79/79 [==============================] - 18s 231ms/step - loss: 0.0346 - accuracy: 0.9905 - val_loss: 0.8577 - val_accuracy: 0.8690
# Epoch 174/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0253 - accuracy: 0.9922 - val_loss: 0.8055 - val_accuracy: 0.8742
# Epoch 175/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0377 - accuracy: 0.9888 - val_loss: 0.8140 - val_accuracy: 0.8675
# Epoch 176/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0277 - accuracy: 0.9919 - val_loss: 0.7794 - val_accuracy: 0.8657
# Epoch 177/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0267 - accuracy: 0.9918 - val_loss: 0.8023 - val_accuracy: 0.8654
# Epoch 178/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0311 - accuracy: 0.9906 - val_loss: 0.8445 - val_accuracy: 0.8597
# Epoch 179/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0308 - accuracy: 0.9909 - val_loss: 0.8322 - val_accuracy: 0.8649
# Epoch 180/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0318 - accuracy: 0.9902 - val_loss: 0.7536 - val_accuracy: 0.8720
# Epoch 181/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0290 - accuracy: 0.9914 - val_loss: 0.7867 - val_accuracy: 0.8744
# Epoch 182/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0290 - accuracy: 0.9909 - val_loss: 0.8671 - val_accuracy: 0.8593
# Epoch 183/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0282 - accuracy: 0.9920 - val_loss: 0.8207 - val_accuracy: 0.8628
# Epoch 184/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0277 - accuracy: 0.9912 - val_loss: 0.7882 - val_accuracy: 0.8693
# Epoch 185/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0289 - accuracy: 0.9915 - val_loss: 0.7788 - val_accuracy: 0.8695
# Epoch 186/200
# 79/79 [==============================] - 18s 231ms/step - loss: 0.0277 - accuracy: 0.9921 - val_loss: 0.8266 - val_accuracy: 0.8605
# Epoch 187/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0274 - accuracy: 0.9923 - val_loss: 0.7493 - val_accuracy: 0.8696
# Epoch 188/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0262 - accuracy: 0.9923 - val_loss: 0.8121 - val_accuracy: 0.8682
# Epoch 189/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0253 - accuracy: 0.9926 - val_loss: 0.8161 - val_accuracy: 0.8654
# Epoch 190/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0293 - accuracy: 0.9918 - val_loss: 0.8127 - val_accuracy: 0.8622
# Epoch 191/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0225 - accuracy: 0.9930 - val_loss: 0.7794 - val_accuracy: 0.8722
# Epoch 192/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0252 - accuracy: 0.9925 - val_loss: 0.7946 - val_accuracy: 0.8671
# Epoch 193/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0238 - accuracy: 0.9930 - val_loss: 0.7744 - val_accuracy: 0.8677
# Epoch 194/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0380 - accuracy: 0.9884 - val_loss: 0.7309 - val_accuracy: 0.8681
# Epoch 195/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0318 - accuracy: 0.9905 - val_loss: 0.8344 - val_accuracy: 0.8570
# Epoch 196/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0287 - accuracy: 0.9915 - val_loss: 0.7829 - val_accuracy: 0.8581
# Epoch 197/200
# 79/79 [==============================] - 18s 224ms/step - loss: 0.0284 - accuracy: 0.9920 - val_loss: 0.7865 - val_accuracy: 0.8674
# Epoch 198/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0242 - accuracy: 0.9926 - val_loss: 0.8578 - val_accuracy: 0.8647
# Epoch 199/200
# 79/79 [==============================] - 18s 225ms/step - loss: 0.0233 - accuracy: 0.9936 - val_loss: 0.8288 - val_accuracy: 0.8673
# Epoch 200/200
# 79/79 [==============================] - 18s 230ms/step - loss: 0.0250 - accuracy: 0.9930 - val_loss: 0.7780 - val_accuracy: 0.8727

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 1:00:26.545280

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 86.590

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
