# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

model = models.Sequential()

# First layer
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Second layer
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Third layer
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# fourth layer

model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# fifth layer

model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3,3), strides=1, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# final
model.add(ks.layers.Flatten())
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(ks.layers.Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 128)         │           3,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 4, 4, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 4, 4, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 4, 4, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 4, 4, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 2, 2, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 2, 2, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 2, 2, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 2, 2, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,371,338 (5.23 MB)
#  Trainable params: 1,368,778 (5.22 MB)
#  Non-trainable params: 2,560 (10.00 KB)

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 5. Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.4, 1.4],
    shear_range=0.2,
    channel_shift_range=0.2,
    fill_mode='nearest',
    validation_split=0.2





    )

train_generator = train_datagen.flow(
    x_train_scaled,
    y_train,
    batch_size=30
)

validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val_scaled,
    y_val,
    batch_size=20
)

# %%
import random
sample = random.choice(range(0,1457))

example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=20
    )

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_scaled, y_train, epochs=300,
                    validation_data=(x_val_scaled, y_val), batch_size=512,
                    )
# Out:
# Epoch 1/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 61s 402ms/step - accuracy: 0.1450 - loss: 2.4649 - val_accuracy: 0.1025 - val_loss: 2.3699
# Epoch 2/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.2707 - loss: 1.8488 - val_accuracy: 0.1031 - val_loss: 2.8006
# Epoch 3/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - accuracy: 0.3841 - loss: 1.5813 - val_accuracy: 0.1136 - val_loss: 2.9074
# Epoch 4/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - accuracy: 0.4882 - loss: 1.3802 - val_accuracy: 0.1354 - val_loss: 3.1716
# Epoch 5/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.5706 - loss: 1.2230 - val_accuracy: 0.1254 - val_loss: 3.2689
# Epoch 6/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.6372 - loss: 1.0655 - val_accuracy: 0.3666 - val_loss: 1.8824
# Epoch 7/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.6899 - loss: 0.9300 - val_accuracy: 0.6200 - val_loss: 1.1265
# Epoch 8/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.7169 - loss: 0.8595 - val_accuracy: 0.6710 - val_loss: 0.9963
# Epoch 9/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.7496 - loss: 0.7733 - val_accuracy: 0.7387 - val_loss: 0.8054
# Epoch 10/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 176ms/step - accuracy: 0.7696 - loss: 0.7138 - val_accuracy: 0.7363 - val_loss: 0.7996
# Epoch 11/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.7923 - loss: 0.6499 - val_accuracy: 0.7746 - val_loss: 0.7009
# Epoch 12/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.8147 - loss: 0.5816 - val_accuracy: 0.6353 - val_loss: 1.3331
# Epoch 13/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.8206 - loss: 0.5699 - val_accuracy: 0.7979 - val_loss: 0.6313
# Epoch 14/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.8327 - loss: 0.5236 - val_accuracy: 0.7364 - val_loss: 0.8735
# Epoch 15/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.8375 - loss: 0.5167 - val_accuracy: 0.7766 - val_loss: 0.7011
# Epoch 16/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.8480 - loss: 0.4765 - val_accuracy: 0.7755 - val_loss: 0.7579
# Epoch 17/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - accuracy: 0.8638 - loss: 0.4399 - val_accuracy: 0.7547 - val_loss: 0.8623
# Epoch 18/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.8766 - loss: 0.3939 - val_accuracy: 0.8078 - val_loss: 0.6276
# Epoch 19/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.8831 - loss: 0.3690 - val_accuracy: 0.7873 - val_loss: 0.7503
# Epoch 20/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 176ms/step - accuracy: 0.8930 - loss: 0.3361 - val_accuracy: 0.8276 - val_loss: 0.5665
# Epoch 21/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.8964 - loss: 0.3353 - val_accuracy: 0.7968 - val_loss: 0.6942
# Epoch 22/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9020 - loss: 0.3155 - val_accuracy: 0.8182 - val_loss: 0.6085
# Epoch 23/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9088 - loss: 0.2930 - val_accuracy: 0.8289 - val_loss: 0.5899
# Epoch 24/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9129 - loss: 0.2824 - val_accuracy: 0.8359 - val_loss: 0.5514
# Epoch 25/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 176ms/step - accuracy: 0.9203 - loss: 0.2492 - val_accuracy: 0.8148 - val_loss: 0.6342
# Epoch 26/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.9178 - loss: 0.2662 - val_accuracy: 0.8407 - val_loss: 0.5722
# Epoch 27/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.9210 - loss: 0.2549 - val_accuracy: 0.8290 - val_loss: 0.6168
# Epoch 28/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 176ms/step - accuracy: 0.9329 - loss: 0.2184 - val_accuracy: 0.8322 - val_loss: 0.5887
# Epoch 29/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9367 - loss: 0.2065 - val_accuracy: 0.8398 - val_loss: 0.5736
# Epoch 30/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9374 - loss: 0.2011 - val_accuracy: 0.8439 - val_loss: 0.5725
# Epoch 31/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9396 - loss: 0.1983 - val_accuracy: 0.8253 - val_loss: 0.6302
# Epoch 32/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9395 - loss: 0.1907 - val_accuracy: 0.8470 - val_loss: 0.5656
# Epoch 33/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9482 - loss: 0.1666 - val_accuracy: 0.8448 - val_loss: 0.5826
# Epoch 34/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9410 - loss: 0.1927 - val_accuracy: 0.8371 - val_loss: 0.6763
# Epoch 35/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9449 - loss: 0.1773 - val_accuracy: 0.8049 - val_loss: 0.7865
# Epoch 36/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9472 - loss: 0.1688 - val_accuracy: 0.8451 - val_loss: 0.6157
# Epoch 37/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9482 - loss: 0.1672 - val_accuracy: 0.8156 - val_loss: 0.7347
# Epoch 38/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - accuracy: 0.9489 - loss: 0.1715 - val_accuracy: 0.8502 - val_loss: 0.5882
# Epoch 39/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9530 - loss: 0.1555 - val_accuracy: 0.8479 - val_loss: 0.5876
# Epoch 40/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9563 - loss: 0.1387 - val_accuracy: 0.8451 - val_loss: 0.6237
# Epoch 41/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9616 - loss: 0.1290 - val_accuracy: 0.8464 - val_loss: 0.6333
# Epoch 42/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9656 - loss: 0.1141 - val_accuracy: 0.8537 - val_loss: 0.5971
# Epoch 43/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9643 - loss: 0.1112 - val_accuracy: 0.8501 - val_loss: 0.6286
# Epoch 44/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9683 - loss: 0.1082 - val_accuracy: 0.8230 - val_loss: 0.7431
# Epoch 45/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9639 - loss: 0.1208 - val_accuracy: 0.8471 - val_loss: 0.6101
# Epoch 46/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9570 - loss: 0.1414 - val_accuracy: 0.8477 - val_loss: 0.6117
# Epoch 47/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9612 - loss: 0.1310 - val_accuracy: 0.8408 - val_loss: 0.7011
# Epoch 48/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9667 - loss: 0.1094 - val_accuracy: 0.8216 - val_loss: 0.7495
# Epoch 49/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - accuracy: 0.9712 - loss: 0.0950 - val_accuracy: 0.8518 - val_loss: 0.6395
# Epoch 50/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9693 - loss: 0.0977 - val_accuracy: 0.8562 - val_loss: 0.6178
# Epoch 51/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9726 - loss: 0.0933 - val_accuracy: 0.8547 - val_loss: 0.6241
# Epoch 52/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9677 - loss: 0.1064 - val_accuracy: 0.8598 - val_loss: 0.5931
# Epoch 53/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9727 - loss: 0.0928 - val_accuracy: 0.8552 - val_loss: 0.6120
# Epoch 54/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9681 - loss: 0.1045 - val_accuracy: 0.8578 - val_loss: 0.6231
# Epoch 55/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9711 - loss: 0.0912 - val_accuracy: 0.8377 - val_loss: 0.7007
# Epoch 56/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9693 - loss: 0.1042 - val_accuracy: 0.8453 - val_loss: 0.6943
# Epoch 57/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9747 - loss: 0.0855 - val_accuracy: 0.8531 - val_loss: 0.6146
# Epoch 58/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9776 - loss: 0.0765 - val_accuracy: 0.8604 - val_loss: 0.6069
# Epoch 59/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9770 - loss: 0.0703 - val_accuracy: 0.8598 - val_loss: 0.6436
# Epoch 60/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9762 - loss: 0.0791 - val_accuracy: 0.8564 - val_loss: 0.6458
# Epoch 61/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9755 - loss: 0.0806 - val_accuracy: 0.8571 - val_loss: 0.6343
# Epoch 62/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9724 - loss: 0.0882 - val_accuracy: 0.8478 - val_loss: 0.6725
# Epoch 63/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9738 - loss: 0.0907 - val_accuracy: 0.8622 - val_loss: 0.6249
# Epoch 64/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.9752 - loss: 0.0854 - val_accuracy: 0.8601 - val_loss: 0.6323
# Epoch 65/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9747 - loss: 0.0852 - val_accuracy: 0.8522 - val_loss: 0.6470
# Epoch 66/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9742 - loss: 0.0843 - val_accuracy: 0.8382 - val_loss: 0.7685
# Epoch 67/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9814 - loss: 0.0631 - val_accuracy: 0.8573 - val_loss: 0.6917
# Epoch 68/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - accuracy: 0.9794 - loss: 0.0683 - val_accuracy: 0.8459 - val_loss: 0.7803
# Epoch 69/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9811 - loss: 0.0653 - val_accuracy: 0.8335 - val_loss: 0.8053
# Epoch 70/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9783 - loss: 0.0724 - val_accuracy: 0.8621 - val_loss: 0.5999
# Epoch 71/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.9820 - loss: 0.0595 - val_accuracy: 0.8555 - val_loss: 0.6445
# Epoch 72/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - accuracy: 0.9827 - loss: 0.0599 - val_accuracy: 0.8487 - val_loss: 0.6627
# Epoch 73/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9789 - loss: 0.0710 - val_accuracy: 0.8582 - val_loss: 0.7097
# Epoch 74/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9827 - loss: 0.0565 - val_accuracy: 0.8641 - val_loss: 0.6482
# Epoch 75/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9843 - loss: 0.0517 - val_accuracy: 0.8400 - val_loss: 0.7646
# Epoch 76/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9730 - loss: 0.0906 - val_accuracy: 0.8534 - val_loss: 0.6621
# Epoch 77/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9739 - loss: 0.0870 - val_accuracy: 0.8541 - val_loss: 0.7112
# Epoch 78/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9809 - loss: 0.0621 - val_accuracy: 0.8553 - val_loss: 0.6552
# Epoch 79/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9797 - loss: 0.0641 - val_accuracy: 0.8574 - val_loss: 0.7119
# Epoch 80/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.9766 - loss: 0.0810 - val_accuracy: 0.8584 - val_loss: 0.6945
# Epoch 81/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9827 - loss: 0.0592 - val_accuracy: 0.8534 - val_loss: 0.6989
# Epoch 82/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9830 - loss: 0.0548 - val_accuracy: 0.8621 - val_loss: 0.6566
# Epoch 83/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9844 - loss: 0.0508 - val_accuracy: 0.8547 - val_loss: 0.6856
# Epoch 84/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9844 - loss: 0.0541 - val_accuracy: 0.8559 - val_loss: 0.7001
# Epoch 85/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9817 - loss: 0.0626 - val_accuracy: 0.8570 - val_loss: 0.6508
# Epoch 86/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.9863 - loss: 0.0467 - val_accuracy: 0.8682 - val_loss: 0.6538
# Epoch 87/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - accuracy: 0.9823 - loss: 0.0656 - val_accuracy: 0.8539 - val_loss: 0.7042
# Epoch 88/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9782 - loss: 0.0745 - val_accuracy: 0.8598 - val_loss: 0.6376
# Epoch 89/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9849 - loss: 0.0481 - val_accuracy: 0.8656 - val_loss: 0.6965
# Epoch 90/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9767 - loss: 0.0770 - val_accuracy: 0.8614 - val_loss: 0.6573
# Epoch 91/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9828 - loss: 0.0584 - val_accuracy: 0.8538 - val_loss: 0.6747
# Epoch 92/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9696 - loss: 0.1047 - val_accuracy: 0.8563 - val_loss: 0.6666
# Epoch 93/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9827 - loss: 0.0579 - val_accuracy: 0.8580 - val_loss: 0.6927
# Epoch 94/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9866 - loss: 0.0451 - val_accuracy: 0.8632 - val_loss: 0.6727
# Epoch 95/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9842 - loss: 0.0539 - val_accuracy: 0.8622 - val_loss: 0.6647
# Epoch 96/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9878 - loss: 0.0422 - val_accuracy: 0.8433 - val_loss: 0.7887
# Epoch 97/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9877 - loss: 0.0416 - val_accuracy: 0.8656 - val_loss: 0.6881
# Epoch 98/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9877 - loss: 0.0416 - val_accuracy: 0.8620 - val_loss: 0.6864
# Epoch 99/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9837 - loss: 0.0550 - val_accuracy: 0.8654 - val_loss: 0.6592
# Epoch 100/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9878 - loss: 0.0383 - val_accuracy: 0.8582 - val_loss: 0.6793
# Epoch 101/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - accuracy: 0.9857 - loss: 0.0489 - val_accuracy: 0.8655 - val_loss: 0.6534
# Epoch 102/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9867 - loss: 0.0410 - val_accuracy: 0.8686 - val_loss: 0.6869
# Epoch 103/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.9870 - loss: 0.0421 - val_accuracy: 0.8607 - val_loss: 0.6894
# Epoch 104/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9854 - loss: 0.0508 - val_accuracy: 0.8599 - val_loss: 0.6925
# Epoch 105/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9856 - loss: 0.0502 - val_accuracy: 0.8651 - val_loss: 0.6871
# Epoch 106/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9844 - loss: 0.0572 - val_accuracy: 0.8697 - val_loss: 0.6495
# Epoch 107/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9877 - loss: 0.0411 - val_accuracy: 0.8549 - val_loss: 0.7633
# Epoch 108/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9773 - loss: 0.0785 - val_accuracy: 0.8596 - val_loss: 0.6901
# Epoch 109/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9862 - loss: 0.0480 - val_accuracy: 0.8708 - val_loss: 0.6522
# Epoch 110/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9829 - loss: 0.0585 - val_accuracy: 0.8528 - val_loss: 0.6614
# Epoch 111/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9882 - loss: 0.0439 - val_accuracy: 0.8714 - val_loss: 0.6322
# Epoch 112/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9833 - loss: 0.0582 - val_accuracy: 0.8648 - val_loss: 0.7052
# Epoch 113/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9879 - loss: 0.0389 - val_accuracy: 0.8661 - val_loss: 0.6934
# Epoch 114/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - accuracy: 0.9856 - loss: 0.0519 - val_accuracy: 0.8529 - val_loss: 0.7300
# Epoch 115/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9882 - loss: 0.0412 - val_accuracy: 0.8646 - val_loss: 0.6702
# Epoch 116/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9907 - loss: 0.0321 - val_accuracy: 0.8241 - val_loss: 0.9760
# Epoch 117/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9853 - loss: 0.0485 - val_accuracy: 0.8618 - val_loss: 0.7056
# Epoch 118/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9888 - loss: 0.0392 - val_accuracy: 0.8638 - val_loss: 0.6972
# Epoch 119/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9889 - loss: 0.0396 - val_accuracy: 0.8692 - val_loss: 0.6946
# Epoch 120/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9877 - loss: 0.0434 - val_accuracy: 0.8679 - val_loss: 0.6486
# Epoch 121/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 176ms/step - accuracy: 0.9885 - loss: 0.0380 - val_accuracy: 0.8596 - val_loss: 0.7386
# Epoch 122/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.9879 - loss: 0.0409 - val_accuracy: 0.8609 - val_loss: 0.7474
# Epoch 123/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9868 - loss: 0.0410 - val_accuracy: 0.8544 - val_loss: 0.7607
# Epoch 124/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9859 - loss: 0.0462 - val_accuracy: 0.8604 - val_loss: 0.7042
# Epoch 125/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9883 - loss: 0.0397 - val_accuracy: 0.8662 - val_loss: 0.6844
# Epoch 126/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9873 - loss: 0.0447 - val_accuracy: 0.8658 - val_loss: 0.6841
# Epoch 127/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9900 - loss: 0.0351 - val_accuracy: 0.8551 - val_loss: 0.7605
# Epoch 128/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - accuracy: 0.9877 - loss: 0.0430 - val_accuracy: 0.8652 - val_loss: 0.7314
# Epoch 129/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9892 - loss: 0.0371 - val_accuracy: 0.8706 - val_loss: 0.6657
# Epoch 130/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9898 - loss: 0.0347 - val_accuracy: 0.8693 - val_loss: 0.6546
# Epoch 131/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9846 - loss: 0.0498 - val_accuracy: 0.8547 - val_loss: 0.7073
# Epoch 132/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9871 - loss: 0.0426 - val_accuracy: 0.8707 - val_loss: 0.6234
# Epoch 133/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9902 - loss: 0.0331 - val_accuracy: 0.8602 - val_loss: 0.7174
# Epoch 134/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9882 - loss: 0.0409 - val_accuracy: 0.8637 - val_loss: 0.7311
# Epoch 135/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9865 - loss: 0.0441 - val_accuracy: 0.8662 - val_loss: 0.7062
# Epoch 136/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9859 - loss: 0.0460 - val_accuracy: 0.8608 - val_loss: 0.7115
# Epoch 137/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - accuracy: 0.9854 - loss: 0.0514 - val_accuracy: 0.8580 - val_loss: 0.7376
# Epoch 138/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9886 - loss: 0.0380 - val_accuracy: 0.8591 - val_loss: 0.7330
# Epoch 139/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9905 - loss: 0.0326 - val_accuracy: 0.8729 - val_loss: 0.6653
# Epoch 140/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9901 - loss: 0.0340 - val_accuracy: 0.8661 - val_loss: 0.7022
# Epoch 141/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9903 - loss: 0.0327 - val_accuracy: 0.8645 - val_loss: 0.7124
# Epoch 142/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 176ms/step - accuracy: 0.9897 - loss: 0.0318 - val_accuracy: 0.8737 - val_loss: 0.6337
# Epoch 143/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9902 - loss: 0.0354 - val_accuracy: 0.8632 - val_loss: 0.7231
# Epoch 144/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9886 - loss: 0.0413 - val_accuracy: 0.8576 - val_loss: 0.7577
# Epoch 145/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9912 - loss: 0.0287 - val_accuracy: 0.8664 - val_loss: 0.6853
# Epoch 146/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9905 - loss: 0.0326 - val_accuracy: 0.8728 - val_loss: 0.6632
# Epoch 147/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9882 - loss: 0.0449 - val_accuracy: 0.8663 - val_loss: 0.6657
# Epoch 148/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9892 - loss: 0.0383 - val_accuracy: 0.8684 - val_loss: 0.6872
# Epoch 149/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9904 - loss: 0.0311 - val_accuracy: 0.8566 - val_loss: 0.7525
# Epoch 150/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9897 - loss: 0.0341 - val_accuracy: 0.8629 - val_loss: 0.7318
# Epoch 151/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9913 - loss: 0.0289 - val_accuracy: 0.8715 - val_loss: 0.7069
# Epoch 152/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9932 - loss: 0.0245 - val_accuracy: 0.8618 - val_loss: 0.7623
# Epoch 153/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9898 - loss: 0.0337 - val_accuracy: 0.8625 - val_loss: 0.7242
# Epoch 154/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9915 - loss: 0.0321 - val_accuracy: 0.8625 - val_loss: 0.7155
# Epoch 155/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.9890 - loss: 0.0381 - val_accuracy: 0.8613 - val_loss: 0.6700
# Epoch 156/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 176ms/step - accuracy: 0.9876 - loss: 0.0435 - val_accuracy: 0.8625 - val_loss: 0.7449
# Epoch 157/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9922 - loss: 0.0298 - val_accuracy: 0.8674 - val_loss: 0.7237
# Epoch 158/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.9906 - loss: 0.0337 - val_accuracy: 0.8707 - val_loss: 0.6649
# Epoch 159/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9897 - loss: 0.0351 - val_accuracy: 0.8630 - val_loss: 0.7414
# Epoch 160/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - accuracy: 0.9919 - loss: 0.0293 - val_accuracy: 0.8625 - val_loss: 0.7272
# Epoch 161/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9865 - loss: 0.0419 - val_accuracy: 0.8684 - val_loss: 0.7118
# Epoch 162/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9915 - loss: 0.0287 - val_accuracy: 0.8690 - val_loss: 0.7221
# Epoch 163/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9818 - loss: 0.0684 - val_accuracy: 0.8669 - val_loss: 0.6705
# Epoch 164/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9836 - loss: 0.0553 - val_accuracy: 0.8614 - val_loss: 0.7005
# Epoch 165/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.9880 - loss: 0.0412 - val_accuracy: 0.8712 - val_loss: 0.6922
# Epoch 166/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9912 - loss: 0.0326 - val_accuracy: 0.8689 - val_loss: 0.7252
# Epoch 167/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9910 - loss: 0.0287 - val_accuracy: 0.8702 - val_loss: 0.6835
# Epoch 168/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9916 - loss: 0.0305 - val_accuracy: 0.8725 - val_loss: 0.6663
# Epoch 169/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9906 - loss: 0.0306 - val_accuracy: 0.8579 - val_loss: 0.7939
# Epoch 170/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9913 - loss: 0.0316 - val_accuracy: 0.8629 - val_loss: 0.7409
# Epoch 171/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9862 - loss: 0.0449 - val_accuracy: 0.8702 - val_loss: 0.7019
# Epoch 172/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9918 - loss: 0.0281 - val_accuracy: 0.8689 - val_loss: 0.7306
# Epoch 173/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9930 - loss: 0.0247 - val_accuracy: 0.8630 - val_loss: 0.7796
# Epoch 174/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9904 - loss: 0.0304 - val_accuracy: 0.8687 - val_loss: 0.7080
# Epoch 175/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 176ms/step - accuracy: 0.9920 - loss: 0.0284 - val_accuracy: 0.8690 - val_loss: 0.6979
# Epoch 176/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9913 - loss: 0.0309 - val_accuracy: 0.8707 - val_loss: 0.7238
# Epoch 177/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9936 - loss: 0.0224 - val_accuracy: 0.8595 - val_loss: 0.8595
# Epoch 178/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9929 - loss: 0.0234 - val_accuracy: 0.8660 - val_loss: 0.7773
# Epoch 179/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - accuracy: 0.9906 - loss: 0.0317 - val_accuracy: 0.8644 - val_loss: 0.7648
# Epoch 180/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9839 - loss: 0.0569 - val_accuracy: 0.8604 - val_loss: 0.6947
# Epoch 181/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9899 - loss: 0.0341 - val_accuracy: 0.8681 - val_loss: 0.7162
# Epoch 182/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.9930 - loss: 0.0235 - val_accuracy: 0.8633 - val_loss: 0.7728
# Epoch 183/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 168ms/step - accuracy: 0.9924 - loss: 0.0253 - val_accuracy: 0.8703 - val_loss: 0.7352
# Epoch 184/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9934 - loss: 0.0233 - val_accuracy: 0.8694 - val_loss: 0.7530
# Epoch 185/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9942 - loss: 0.0203 - val_accuracy: 0.8668 - val_loss: 0.7564
# Epoch 186/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - accuracy: 0.9932 - loss: 0.0243 - val_accuracy: 0.8709 - val_loss: 0.7235
# Epoch 187/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9919 - loss: 0.0275 - val_accuracy: 0.8696 - val_loss: 0.7056
# Epoch 188/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9924 - loss: 0.0268 - val_accuracy: 0.8727 - val_loss: 0.7023
# Epoch 189/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.9918 - loss: 0.0276 - val_accuracy: 0.8700 - val_loss: 0.7171
# Epoch 190/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 167ms/step - accuracy: 0.9931 - loss: 0.0241 - val_accuracy: 0.8694 - val_loss: 0.7330
# Epoch 191/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 174ms/step - accuracy: 0.9934 - loss: 0.0229 - val_accuracy: 0.8614 - val_loss: 0.7959
# Epoch 192/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 166ms/step - accuracy: 0.9889 - loss: 0.0473 - val_accuracy: 0.8432 - val_loss: 0.8389
# Epoch 193/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - accuracy: 0.9907 - loss: 0.0303 - val_accuracy: 0.8715 - val_loss: 0.6757
# Epoch 194/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 172ms/step - accuracy: 0.9922 - loss: 0.0255 - val_accuracy: 0.8693 - val_loss: 0.6996
# Epoch 195/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 168ms/step - accuracy: 0.9927 - loss: 0.0248 - val_accuracy: 0.8706 - val_loss: 0.7130
# Epoch 196/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 170ms/step - accuracy: 0.9929 - loss: 0.0265 - val_accuracy: 0.8735 - val_loss: 0.7338
# Epoch 197/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9914 - loss: 0.0328 - val_accuracy: 0.8592 - val_loss: 0.7551
# Epoch 198/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9886 - loss: 0.0366 - val_accuracy: 0.8716 - val_loss: 0.6675
# Epoch 199/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.9914 - loss: 0.0288 - val_accuracy: 0.8686 - val_loss: 0.6982
# Epoch 200/200
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - accuracy: 0.9920 - loss: 0.0241 - val_accuracy: 0.8642 - val_loss: 0.7967

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 1:03:39.212158

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 85.940

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
